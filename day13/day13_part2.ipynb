# %%
import numpy as np


with open("input.txt") as f:
    lines = f.readlines()
    blocus = []
    curr = []
    for line in lines:
        if line == '\n':
            blocus.append(np.array(curr))
            curr = []
        else:
            curr.append(list(line.strip('\n')))
    blocus.append(np.array(curr))
blocus
# Out:
# [array([['.', '#', '#', '.', '.', '.', '#', '.', '.', '#', '#'],
#         ['.', '.', '.', '.', '.', '#', '#', '.', '.', '.', '#'],
#         ['#', '.', '.', '#', '.', '.', '#', '#', '#', '.', '.'],
#         ['#', '.', '.', '#', '#', '#', '#', '#', '.', '.', '#'],
#         ['#', '#', '#', '#', '.', '#', '#', '.', '#', '#', '.'],
#         ['#', '#', '#', '#', '.', '#', '#', '.', '#', '#', '.'],
#         ['#', '.', '.', '#', '#', '#', '#', '#', '.', '.', '#'],
#         ['#', '.', '.', '#', '#', '.', '#', '#', '#', '.', '.'],
#         ['.', '.', '.', '.', '.', '#', '#', '.', '.', '.', '#'],
#         ['.', '#', '#', '.', '.', '.', '#', '.', '.', '#', '#'],
#         ['.', '#', '#', '.', '.', '#', '.', '#', '#', '.', '#'],
#         ['.', '.', '.', '.', '.', '.', '.', '.', '#', '#', '#'],
#         ['.', '.', '.', '.', '.', '#', '.', '.', '.', '#', '.'],
#         ['.', '.', '.', '.', '#', '.', '#', '.', '#', '#', '.'],
# ...

# %%
def get_row_idx(has_modif):
    modif_coord = ()
    modif = None
    for i in range(n-1):
        j = 1
        while i-j+1 >= 0 and i+j < n and ((arr[i-j+1] == arr[i+j]).all() or (arr[i-j+1] != arr[i+j]).sum() == 1):
            if (arr[i-j+1] != arr[i+j]).sum() == 1:
                if not has_modif:
                    for e in range(m):
                        if arr[i-j+1,e] != arr[i+j,e]:
                            modif_coord = (i+j, e)
                            modif = arr[i+j,e]
                            arr[i+j,e] = arr[i-j+1,e]
                            has_modif = True
                else:
                    break

            j+=1

            if (i-j+1 < 0 or i+j >= n) and has_modif:
                return i+1
        if has_modif:
            arr[modif_coord] = modif
            has_modif = False


            
    return 0

def get_col_idx(has_modif):
    modif_coord = ()
    modif = None

    for i in range(m-1):
        j = 1
        while i-j+1 >= 0 and i+j < m and ((arr[:,i-j+1] == arr[:, i+j]).all() or (arr[:,i-j+1] != arr[:,i+j]).sum() == 1):
            if (arr[:,i-j+1] != arr[:,i+j]).sum() == 1:
                if not has_modif:
                    for e in range(n):
                        if arr[e,i-j+1] != arr[e,i+j]:
                            modif_coord = (e, i+j)
                            modif = arr[e, i+j]

                            arr[e,i+j] = arr[e,i-j+1]
                            has_modif = True
                else:
                    break
            j+=1

            if (i-j+1 < 0 or i+j >= m) and has_modif:
                return i+1
        if has_modif:
            arr[modif_coord] = modif
            has_modif = False
    return 0

som = 0
for arr in blocus:
    col_idx = 0
    n, m = arr.shape

                
    has_modif = False
    prev = arr.copy()
    row_idx = get_row_idx(False)
    col_idx = get_col_idx(False)

    print(row_idx, col_idx)
    som += col_idx + 100*row_idx

som
# Out:
# 5 0
# 0 8
# 0 6
# 2 0
# 0 12
# 0 5
# 5 0
# 0 5
# 0 2
# 3 0
# 2 0
# 0 2
# 0 2
# 0 12
# 0 10
# 0 9
# 1 0
# 0 3
# 0 6
# 12 0
# 1 0
# 0 5
# 3 0
# 2 0
# 0 6
# 0 6
# 0 12
# 0 4
# 0 8
# 2 0
# 0 5
# 14 0
# 0 10
# 0 8
# 0 1
# 5 0
# 0 6
# 4 0
# 6 0
# 12 0
# 1 0
# 1 0
# 6 0
# 0 5
# 0 13
# 0 6
# 0 7
# 0 6
# 1 0
# 0 5
# 5 0
# 0 8
# 0 5
# 0 14
# 10 0
# 5 0
# 1 0
# 0 6
# 7 0
# 0 7
# 5 0
# 0 13
# 0 9
# 7 0
# 0 6
# 14 0
# 0 9
# 1 0
# 0 14
# 0 7
# 0 6
# 7 0
# 4 0
# 0 3
# 0 16
# 1 0
# 0 4
# 1 0
# 0 11
# 2 0
# 0 6
# 8 0
# 0 9
# 7 0
# 13 0
# 0 9
# 0 3
# 0 2
# 3 0
# 0 8
# 0 3
# 0 13
# 0 8
# 16 0
# 4 0
# 0 11
# 5 0
# 2 0
# 0 1
# 9 0
# 22906
